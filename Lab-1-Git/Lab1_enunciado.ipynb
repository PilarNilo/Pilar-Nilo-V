# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2024</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Sebastián Tinoco
# - Auxiliar: Eduardo Moya
# - Ayudantes: Nicolás Ojeda, Melanie Peña, Valentina Rojas

# %% [markdown]
# ### Equipo: **SUPER IMPORTANTE - notebooks sin nombre no serán revisados**
#
# - Nombre de alumno 1: Pilar Nilo
# - Nombre de alumno 2: Diego Bartolucci

# %% [markdown]
# ### **Link de repositorio de GitHub:** [Enlace](https://github.com/PilarNilo/Pilar-Nilo-V.git)

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: 6 días de plazo con descuento de 1 punto por día. Entregas Jueves a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 1. Git es una herramienta de control de versiones distribuido, es de código abierto, eficiente, colaborativo y flexible, esto ultimo dado que se pueden crear ramas y el usuario puede trabajar en los errores sin afectar al proyecto completo. Se relaciona con el control de versiones por que permite registrar cambios, poder regresar a versiones anteriores y colaborar.
#
# 2.  Diferencia 1 --> Git es un software de control de versiones distribuido y GitHub es una plataforma que ofrece un servicio de almacenamiento en la nube.
#
#     Diferencia 2 --> Git es una herramienta de línea de comando y GitHub entrega una interfaz gráfica.
#
#     Diferencia 3 --> Git crea un repositorio local para trackear los cambios locales y GitHub es un espacio en la nube para subir repositorios Git.
#
# 3. Un HASH es un número de identificación único para cada confirmación dentro de un repositorio de Git, se genera usando una función hash criptografica SHA-1 que produce una cadena de 40 caracteres hexadecimales. Al hacer un commit en uno de los archivos del repositorio, se genera un código hash único el cual permitirá registrar que modificación se hizo y en que archivo se realizó, pero al momento de hacer otra modificación se creará otro hash, diferente al anterior.
#
# 4. Los elementos que componen a la estructura de datos de Git son Blob: Objeto binario grande, Tree: crea jerarquía entre archivos de un repositorio y commit: Confirma un conjunto de cambios.
#
# 5. El comando de Git que sirve para crear un repositorio es git init, si es crear un repositorio a partir de otro (clonar) se usa git clone. Para el seguimiento de los cambios en los archivos se usa git status (después de hacer el commit de los camios realizados).

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 6. Falso. Cuando existe un problema de lineas al hacer merge, Git no sabe como resolverlo automáticamente, ya que no sabe cual de las dos líneas se debe mantener,
# por lo que pide una intervención del desarrollador para resolver la discrepancia.
#
# 7. Falso. Ejecutar git pull sobre un repositorio no es equivalente a ejecutar git clone. Estos dos comandos tienen propósitos diferentes. Mientras que `git clone` se utiliza para crear una copia completa de un repositorio remoto en tu máquina local, `git pull` se utiliza para sincronizar un repositorio local existente con su versión remota.
#
# 8. Falso.  `git status` te entrega el estado presente del repositorio, mientras que `git log` te muestra el historial de cambios que han sido confirmados.
#
# 9. Verdadero. Git ofrece varias herramientas para deshacer cambios y volver a versiones anteriores, como `git checkout`, `git reset`, `git revert` o `git restore`.
#
# 10. Falso. `git commit` se encarga de guardar los cambios localmente, mientras que el encargado de enviar los cambios al repositorio remoto es `git push`.

# %% [markdown]
# Por último, investigue y comente con sus palabras para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 11. `git stash` sirve para alamcenar temporalmente cambios del código para seguir trabajando en otro archivo, así se guardan los cambios en un stash hasta que se vuelva a retomar el trabajo en el código.
#
# 12. `git reset` se encarga de deshacer cambios moviendo la referencia de la rama a un commit anterior. Esto a través de la asignación de un header a un commit específico. La diferencia que este posee con `git revert` se utiliza para deshacer los cambios introducidos por un commit específico, creando un nuevo commit que revierte los cambios sin afectar al historial de commits como `git reset`.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code> https://github.com/PilarNilo/Pilar-Nilo-V.git
#
# <code>Link Presentacion 2:</code> https://github.com/DiegoBarto01/DiegoBarto01

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code> git clone https://github.com/MDS7202/lab1.git

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>
#
# #.gitignore
#
# ##ignorar la carpeta text
#
# videos/
#
# ##ignorar los archivos txt exceptuando 171.txt
#
# texts/*.txt
# !texts/171.txt

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# El objetivo del proyecto consiste en que, a través de un input proporcionado por el usuario el cual debe ser el nombre de un animal, se reconozca que sonido emite el animal introducido.
#
# - README.md: Contiene una breve descripción de lo que debe realizar el proyecto además de ser la primera página que verá el usuario al ingresar al repositorio.
#
# - main.py: Archivo principal del repositorio, este es el que se ejecutará para llevar a cabo el objetivo que tiene el proyecto, el cual permite llamar otros archivos del repositorio como en este caso animales.py.
#
# - animales.py: Archivo que posee las función con la que el archivo main.py funciona. Este permite analizar el input introducido por el usuario y entregar una respuesta en base a este.

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# # Principales ramas de trabajo:
#
# - main: Es la rama principal del repositorio, donde se encuentran los commits más recientes y parece ser la rama base para el desarrollo del proyecto.
#
# - fix-ifs: Es una rama de trabajo donde se realizó un commit para corregir una función, posiblemente relacionado con estructuras de control if.
#
# - new_features: Esta rama parece estar enfocada en la implementación de nuevas características, dado que contiene un commit significativo que indica la separación del proyecto en módulos.
#
# # Commits
#
# - Commit b262d86411a6b017e99bf0731e33a6787739247c: "primer commit"
#
# - Commit c8b1a62d7299552b0654f930d695b33109214111: "se agrega funcion"
#
# - Commit 362fe21ee44f53ee944cee4ba484600308f83d78 (HEAD -> main, origin/new_features, origin/main, origin/HEAD): "Se separa el proyecto en modulos"
#
# - Commit 25543a3baf77292baf849726784ca005473acab1 (origin/fix-ifs): "fix ifs"
#
# # Informativo
#
# En base a los comentarios incluidos en cada commit se puede dar una idea de que se realiza en cada uno de estos, pero no se puede comprender en su totalidad solo por estos sino que en algunos casos como "se agrega funcion" se necesita de analizar el código proporcionado para enteder que se agregó completamente.

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Al probar el archivo main.py nos damos cuenta de que al ingresar las opciones de perro y gato, no funciona correctamente la función debido a la falta del uso de 'elif' en vez de solo 'if'. Con git blame animales.py analizaremos quien es el responsable de la generación de este código.
#
# <code>
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  1) def animales(input):
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  2)
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  3)     '''
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  4)     Como hace el animalito?
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  5)     '''
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  6)
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  7)     if input.lower() == 'gato':
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  8)         print('miau')
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  9)     if input.lower() == 'perro':
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 10)         print('guau')
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 11)     if input.lower() == 'fox':
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 12)         print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 13)     else:
#
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 14)         raise ValueError('animal no reconocido :(')
#
# </code>
#
# Con esto nos damos cuenta de que el responsable es mezosky el dia 23-03-2023.

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# para visualizar cada hash se utilizó git show ...Hash..., luego de esto cada uno mostraba información de lo que había modificado y el nombre asociado al commit. Las diferencias que existen son principalmente en la indicación de donde se hizo el commit (en una rama o en un modulo).
#
# 1. se agrega función y se especifica las líneas de código que se agregaron
# 2. se separa el proyecto en modulos y se puede ver que se trabaja en una de las ramas (main) y se especifica los modulos
#                 commit 362fe21ee44f53ee944cee4ba484600308f83d78 (HEAD -> main, origin/new_features, origin/main, origin/HEAD)
#                 Author: mezosky <ignacio.meza@ug.uchile.cl>
#                 Date:   Thu Mar 23 21:47:34 2023 -0300
#
#                     Se separa el proyecto en modulos
#
#                 diff --git a/animales.py b/animales.py
#                 new file mode 100644
#                 index 0000000..694e39c
#                 --- /dev/null
#                 +++ b/animales.py
#                 @@ -0,0 +1,14 @@
#                 +def animales(input):
#                 +
#                 +    '''
#                 +    Como hace el animalito?
#                 +    '''
#                 +
#                 +    if input.lower() == 'gato':
#                 +        print('miau')
#                 +    if input.lower() == 'perro':
#                 +        print('guau')
#                 +    if input.lower() == 'fox':
#                 +        print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#                 +    else:
#                 +        raise ValueError('animal no reconocido :(')
#                 diff --git a/main.py b/main.py
#                 index a4484fb..b2aa01f 100644
#                 --- a/main.py
#                 +++ b/main.py
#                 @@ -1,19 +1,6 @@
#                 -def animales(input):
#                 -
#                 -    '''
#                 -    Como hace el animalito?
#                 -    '''
#                 -
#                 -    if input.lower() == 'gato':
#                 -        print('miau')
#                 -    if input.lower() == 'perro':
#                 -        print('guau')
#                 -    if input.lower() == 'fox':
#                 -        print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#                 -        raise ValueError('animal no reconocido :(')
#                 +from animales import animales
#
#                 if __name__ == '__main__':
#                     print("Ingrese el animalito para saber que dice:")
#                     animal = input()
#                 -    animales(animal)
#                 \ No newline at end of file
#                 +    animales(animal)
#
# 3. se arreglan las funciones if (fix ifs), además se especifica en que modulo se está realizando la modificación origin/fix-ifs
#             commit 25543a3baf77292baf849726784ca005473acab1 (origin/fix-ifs)
#             Author: Pablo Badilla <pbadilla.torrealba@gmail.com>
#             Date:   Thu Mar 23 22:50:49 2023 -0300
#
#                 fix ifs
#
#             diff --git a/main.py b/main.py
#             index a4484fb..345a51f 100644
#             --- a/main.py
#             +++ b/main.py
#             @@ -6,9 +6,9 @@ def animales(input):
#
#                 if input.lower() == 'gato':
#                     print('miau')
#             -    if input.lower() == 'perro':
#             +    elif input.lower() == 'perro':
#                     print('guau')
#             -    if input.lower() == 'fox':
#             +    elif input.lower() == 'fox':
#                     print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#                 else:
#                     raise ValueError('animal no reconocido :(')
#
# En el código anterior se indica con signo - lo que se quita/cambia y + lo que se va agregando.

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# El resultado es el siguiente usando el comando de la primera línea:
#
#         git merge origin/fix-ifs
#         Auto-merging main.py
#         CONFLICT (content): Merge conflict in main.py
#         Automatic merge failed; fix conflicts and then commit the result.
# El conflicto que se menciona, está ocurriendo en el código de animales.py ya que se modificaron las mismas líneas de código pero en diferentes ramas. La modificación ocurre al cambiar todos los if por elif, cuando debería comenzar con un if, luego solo elif y terminando con un else.

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 1. Para crear una rama nueva usamos git branch new_branch, luego nos cambiamos de rama usando git switch new_branch.
# 2. Revisamos en que rama estamos con git branch y la rama new_branch debería salir acompañada de un asterisco
#         git branch
#         dev
#         * main
#         new_branch
#         PS C:\Users\pilar\Desktop\lab1\lab1> git switch new_branch
#         M       animales.py
#         Switched to branch 'new_branch'
#         PS C:\Users\pilar\Desktop\lab1\lab1> git branch
#         dev
#         main
#         * new_branch
# 3. Corregimos errores en el código animales.py, cambiando todos los if por elif, exceptuando el primer if, el else se mantiene.
#                 def animales(input):
#
#             '''
#             Como hace el animalito?
#             '''
#
#             if input.lower() == 'gato':
#                 print('miau')
#             elif input.lower() == 'perro':
#                 print('guau')
#             elif input.lower() == 'fox':
#                 print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#             else:
#                 raise ValueError('animal no reconocido :(')
# 4. Hacemos el commit  git commit -m "fix ifs animales.py"
# 5. Realizamos el merge con git merge main

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>
